# %% [markdown]
# Import keyword library and print list of keywords along with total number of keywords

# %%
import keyword as key
keyWordList = key.kwlist
print("Number of keywords in Python is : {}. They are : \n{}".format(len(keyWordList),keyWordList))
# Out:
# Number of keywords in Python is : 36. They are :
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
key.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  '__peg_parser__',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# In Markdown State, Copy Python keywords image from Google Images and Paste it in your notebook

# %% [markdown]
# ![keywords.png](attachment:keywords.png)

# %% [markdown]
# Create two strings a and b with any integer values stored in it And perform Addition, Multiplication, Subtraction and a2+b2

# %%
a = int(input("Enter num1 :"))
b = int(input("Enter num2 :"))
addition = a + b
multiplication = a * b
subtraction = a - b
squareAddition = a**2 +b**2

print("Addition of {} and {} is {}".format(a,b,addition))
print("Multiplication of {} and {} is {}".format(a,b,multiplication))
print("Subtraction of {} and {} is {}".format(a,b,subtraction))
print("squareAddition of {}**2 and {}**2 is {}".format(a,b,squareAddition))
# Out:
# Enter num1 :2
# Enter num2 :3
# Addition of 2 and 3 is 5
# Multiplication of 2 and 3 is 6
# Subtraction of 2 and 3 is -1
# squareAddition of 2**2 and 3**2 is 13

# %% [markdown]
#  Use Boolean operators (==, !=, >, >=, <, <= ) , between a and b and Display output

# %%
a=int(input('Enter value of a : '))
b=int(input('Enter value of b : '))

if a == b:
    print('A and b are equal')
elif a != b :
    print('A & B are not equal')
if a > b :
    print('A greater than B')
elif a >= b :
    print('A greater than or equal to B')
elif a < b :
    print('A lesser than B')
elif a <= b :
    print('A lesser than equal to B')
# Out:
# Enter value of a : 4
# Enter value of b : 5
# A & B are not equal
# A lesser than B

# %% [markdown]
# Create two strings x and y with any integer values stored in it And perform bitwise operations (&,^, | ,>>,<<)

# %%
x = int(input('Enter value of X : '))
y = int(input('Enter value of Y : '))

print('The values of x and y : ', x,y)
print('x and y : {}, in binary : {}'.format(x&y, bin(x&y)))
print('x XOR y : {}, in binary : {}'.format(x^y, bin(x^y)))
print('x OR y : {}, in binary : {}'.format(x|y, bin(x|y)))
print('x right shift y : {}, in binary : {} '.format(x>>y,bin(x>>y)))
print('x left shift y : {}, in binary : {}'.format(x<<y,bin(x<<y)))
# Out:
# Enter value of X : 45
# Enter value of Y : 5
# The values of x and y :  45 5
# x and y : 5, in binary : 0b101
# x XOR y : 40, in binary : 0b101000
# x OR y : 45, in binary : 0b101101
# x right shift y : 1, in binary : 0b1
# x left shift y : 1440, in binary : 0b10110100000
